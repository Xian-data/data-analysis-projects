# %%
from utils import concat_data

# 使用
folder_path = r"C:\Users\35104\Desktop"
save_path = r"C:\Users\35104\Desktop"
concat_data(folder_path, save_path)
# Out:
# 合并完成！共 154 行数据
# 保存位置: C:\Users\35104\Desktop\合并结果.xlsx
# c:\Users\35104\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\35104\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
